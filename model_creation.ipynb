# %% [markdown]
# # Emotion Dection

# %% [markdown]
# Importing libraries

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# WARNING:tensorflow:From C:\Users\Shree\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Tensorflow version: 2.15.0

# %% [markdown]
# **Eploring Database**

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off');

# %% [markdown]
# **Preparing dara for training**

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size = (img_size, img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                    target_size = (img_size, img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(inputs,64,(5,5))
    conv_3 = Convolution(inputs,128,(3,3))
    
    flatten = Flatten()(conv_3)
    dense_1 = Dense_f(flatten,256)
    output = Dense(7,activation = "softmax")(dense_1)
    model = Model(inputs=[inputs],outputs=[output])
    
    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])
    
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Shree\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Shree\anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\Shree\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# **Initializing the model**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor = 'val_accuracy', save_weights_only = True, mode= 'max', verbose = 1)
callbacks = [checkpoint]

# %% [markdown]
# # Training The Model

# %% [markdown]
# **The next call takes time to complete**

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\Shree\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Shree\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6499 - accuracy: 0.3758
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 547s 1s/step - loss: 1.6499 - accuracy: 0.3758 - val_loss: 1.5785 - val_accuracy: 0.3857
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3582 - accuracy: 0.4821
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 361s 806ms/step - loss: 1.3582 - accuracy: 0.4821 - val_loss: 1.4574 - val_accuracy: 0.4427
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2013 - accuracy: 0.5485
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 199s 445ms/step - loss: 1.2013 - accuracy: 0.5485 - val_loss: 1.5474 - val_accuracy: 0.4174
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0667 - accuracy: 0.6088
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 187s 417ms/step - loss: 1.0667 - accuracy: 0.6088 - val_loss: 1.5386 - val_accuracy: 0.4215
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9450 - accuracy: 0.6542
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 184s 410ms/step - loss: 0.9450 - accuracy: 0.6542 - val_loss: 1.5029 - val_accuracy: 0.4574
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8207 - accuracy: 0.7009
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 187s 417ms/step - loss: 0.8207 - accuracy: 0.7009 - val_loss: 1.5222 - val_accuracy: 0.4623
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7057 - accuracy: 0.7498
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 181s 404ms/step - loss: 0.7057 - accuracy: 0.7498 - val_loss: 1.5952 - val_accuracy: 0.4693
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6012 - accuracy: 0.7874
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 205s 457ms/step - loss: 0.6012 - accuracy: 0.7874 - val_loss: 1.5455 - val_accuracy: 0.4855
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5167 - accuracy: 0.8174
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 273s 609ms/step - loss: 0.5167 - accuracy: 0.8174 - val_loss: 1.6437 - val_accuracy: 0.4854
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4505 - accuracy: 0.8454
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 182s 406ms/step - loss: 0.4505 - accuracy: 0.8454 - val_loss: 1.6376 - val_accuracy: 0.4828
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3857 - accuracy: 0.8690
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 185s 412ms/step - loss: 0.3857 - accuracy: 0.8690 - val_loss: 1.6983 - val_accuracy: 0.4969
# Epoch 12/15
# 423/448 [===========================>..] - ETA: 9s - loss: 0.3319 - accuracy: 0.8899

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.legend(['Train', 'Validation'],loc = 'upper left')
plt.subplots_adjust(top = 1.0, bottom = 0.0, right = 0.95, left = 0.0, hspace = 0.25, wspace = 0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train', 'Validation'],loc = 'upper left')
plt.subplots_adjust(top = 1.0, bottom = 0.0, right = 0.95, left = 0.0, hspace = 0.25, wspace = 0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json = model.to_json()
with open ("model_a.json","w") as json_file:
    json_file.write(model_json)
